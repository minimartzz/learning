# %% [markdown]
# # DVC Examples
#
# Some code snippets that are useful for using DVC in Python

# %% [markdown]
# | Date | User | Change Type | Remarks |
# | ---- | ---- | ----------- | ------- |
# | 15/01/2026   | Martin | Created   | Notebook created to store some DVC code snippets |

# %% [markdown]
# # Content
#
# * [Using DVC in Python](#using-dvc-in-python)

# %% [markdown]
# # Using DVC in Python

# %%
import dvc.api

# %%
model_path = "model.pkl"
repo_url = 'https://github.com/example/registry'

with dvc.api.open(model_path, repo_url) as f:
  model = pickle.load(f)

# %%
# %load_ext watermark
# %watermark
