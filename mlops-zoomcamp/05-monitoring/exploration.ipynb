# %% [markdown]
# # Exploration Notebook
#
# Notebook used for exploration of tools

# %% [markdown]
# | Date | User | Change Type | Remarks |
# | ---- | ---- | ----------- | ------- |
# | 02/02/2026   | Martin | Created   | Notebook created to explore tools used for ML monitoring |
# | 03/02/2026   | Martin | Update   | Completed Evidently dashboards |

# %% [markdown]
# # Content
#
# * [Baseline Taxi Model w/ Evidently](#baseline-taxi-model-with-evidently)
# * [Evidently Dashboard](#evidently-dashboard)
# * [Testing for Grafana](#testing-for-grafana)

# %% [markdown]
# # Baseline Taxi Model with Evidently
#
# `evidently` is a package that provides a report on model and data drift

# %%
import requests
import datetime
import pandas as pd

from joblib import load, dump
from tqdm import tqdm

from evidently import Dataset, DataDefinition, Report
from evidently.metrics import *
from evidently.presets import *

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
files = [
  ('green_tripdata_2025-01.parquet','../data/raw'),
  ('green_tripdata_2025-02.parquet', '../data/raw'),
  ('green_tripdata_2025-03.parquet', '../data/raw'),
]

print("Download files:")
for file, path in files:
  url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/{file}"
  resp = requests.get(url, stream=True)
  save_path = f"{path}/{file}"
  with open(save_path, "wb") as handle:
    for data in tqdm(resp.iter_content(),
                    desc=f"{file}",
                    postfix=f"save to {save_path}",
                    total=int(resp.headers["Content-Length"])):
      handle.write(data)
# Out:
# Download files:
# green_tripdata_2025-03.parquet: 100%|██████████| 1253510/1253510 [00:03<00:00, 333777.30it/s, save to ../data/raw/green_tripdata_2025-03.parquet]

# %%
jan_data = pd.read_parquet('../data/raw/green_tripdata_2025-01.parquet')
jan_data.describe()
# Out:
#            VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# count  48326.000000                       48326                       48326
# mean       1.870215  2025-01-17 04:19:01.965753  2025-01-17 04:38:59.277448
# min        1.000000         2024-12-25 23:13:15         2024-12-25 23:13:17
# 25%        2.000000  2025-01-09 14:00:31.500000  2025-01-09 14:26:33.500000
# 50%        2.000000  2025-01-16 19:46:55.500000  2025-01-16 20:01:19.500000
# 75%        2.000000  2025-01-24 17:47:35.500000         2025-01-24 18:03:52
# max        2.000000         2025-02-05 18:46:24         2025-02-05 19:11:47
# std        0.336070                         NaN                         NaN
#
#          RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  46490.000000  48326.000000  48326.000000     46490.000000
# mean       1.184771     94.094545    142.409014         1.278103
# min        1.000000      3.000000      1.000000         0.000000
# 25%        1.000000     74.000000     74.000000         1.000000
# 50%        1.000000     75.000000    140.000000         1.000000
# 75%        1.000000     97.000000    230.000000         1.000000
# max       99.000000    265.000000    265.000000         9.000000
# std        1.442502     54.968061     77.251550         0.937178
#
#        trip_distance   fare_amount         extra       mta_tax    tip_amount  \
# count   48326.000000  48326.000000  48326.000000  48326.000000  48326.000000
# mean       21.532410     16.762466      0.932324      0.602776      2.481859
# min         0.000000   -113.000000     -5.000000     -0.500000     -0.900000
# 25%         1.100000      9.300000      0.000000      0.500000      0.000000
# 50%         1.740000     13.500000      0.000000      0.500000      2.070000
# 75%         2.940000     19.100000      2.500000      0.500000      3.690000
# max     84731.570000    336.200000      7.500000      4.250000    252.050000
# std       990.646907     13.308342      1.348587      0.357366      3.213612
#
#        tolls_amount  ehail_fee  improvement_surcharge  total_amount  \
# count  48326.000000        0.0           48326.000000  48326.000000
# mean       0.177461        NaN               0.988346     22.634242
# min        0.000000        NaN              -1.000000   -114.000000
# 25%        0.000000        NaN               1.000000     13.705000
# 50%        0.000000        NaN               1.000000     18.750000
# 75%        0.000000        NaN               1.000000     26.465000
# max       48.760000        NaN               1.000000    371.400000
# std        1.192984        NaN               0.130402     15.435061
#
#        payment_type     trip_type  congestion_surcharge  cbd_congestion_fee
# count  46490.000000  46483.000000           46490.00000        46490.000000
# mean       1.266423      1.038788               0.85306            0.053350
# min        1.000000      1.000000              -2.75000            0.000000
# 25%        1.000000      1.000000               0.00000            0.000000
# 50%        1.000000      1.000000               0.00000            0.000000
# 75%        2.000000      1.000000               2.75000            0.000000
# max        5.000000      2.000000               2.75000            0.750000
# std        0.471842      0.193092               1.27190            0.192788

# %%
jan_data.shape
# Out:
# (48326, 21)

# %%
# Create target - Duration in Minutes
jan_data["duration_min"] = jan_data.lpep_dropoff_datetime - jan_data.lpep_pickup_datetime
jan_data.duration_min = jan_data.duration_min.apply(lambda td : float(td.total_seconds())/60)

# %%
# Filter out outliers
jan_data = jan_data[(jan_data.duration_min >= 0) & (jan_data.duration_min <= 60)]
jan_data = jan_data[(jan_data.passenger_count > 0) & (jan_data.passenger_count <= 8)]

# Drop "ehail_fee column"
jan_data = jan_data.drop("ehail_fee", axis=1)

# %%
jan_data.duration_min.hist()

# %%
# Feb Data
feb_data = pd.read_parquet('../data/raw/green_tripdata_2025-02.parquet')

feb_data["duration_min"] = feb_data.lpep_dropoff_datetime - feb_data.lpep_pickup_datetime
feb_data.duration_min = feb_data.duration_min.apply(lambda td : float(td.total_seconds())/60)
feb_data = feb_data[(feb_data.duration_min >= 0) & (feb_data.duration_min <= 60)]
feb_data = feb_data[(feb_data.passenger_count > 0) & (feb_data.passenger_count <= 8)]
feb_data = feb_data.drop("ehail_fee", axis=1)

# %%
# Data labeling
target = "duration_min"
num_features = ["passenger_count", "trip_distance", "fare_amount", "total_amount"]
cat_features = ["PULocationID", "DOLocationID"]

# %% [markdown]
# ## Baseline Model
#
# Using `LinearRegression`

# %%
train_data = jan_data[:30000]
val_data = jan_data[30000:]

# %%
model = LinearRegression()
model.fit(train_data[num_features + cat_features], train_data[target])
# Out:
# LinearRegression()

# %%
train_preds = model.predict(train_data[num_features + cat_features])
train_data['prediction'] = train_preds

val_preds = model.predict(val_data[num_features + cat_features])
val_data['prediction'] = val_preds

print(mean_absolute_error(train_data.duration_min, train_data.prediction))
print(mean_absolute_error(val_data.duration_min, val_data.prediction))
# Out:
# 3.7376346650222163
# 3.636921395503821

# %%
# Save the model and test data
with open('models/lin_reg.bin', 'wb') as f_out:
  dump(model, f_out)

val_data.to_parquet('../data/clean/reference.parquet')

# %% [markdown]
# ## Creating evidently report

# %%
val_data.head()
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 30768         2  2025-01-22 12:07:38   2025-01-22 12:12:20                  N
# 30769         2  2025-01-22 12:52:31   2025-01-22 13:06:00                  N
# 30770         2  2025-01-22 12:04:37   2025-01-22 12:14:03                  N
# 30771         1  2025-01-22 12:15:39   2025-01-22 12:19:47                  N
# 30772         2  2025-01-22 12:08:19   2025-01-22 12:08:40                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 30768         1.0            74            42              1.0           0.47
# 30769         1.0            75            43              1.0           2.03
# 30770         1.0            41           166              1.0           1.28
# 30771         1.0             7             7              1.0           0.50
# 30772         1.0            74            41              1.0           0.10
#
#        fare_amount  ...  tip_amount  tolls_amount  improvement_surcharge  \
# 30768          6.5  ...        1.60           0.0                    1.0
# 30769         14.9  ...        3.83           0.0                    1.0
# 30770         10.7  ...        2.44           0.0                    1.0
# 30771          5.8  ...        0.00           0.0                    1.0
# 30772          3.0  ...        0.00           0.0                    1.0
#
#        total_amount  payment_type  trip_type  congestion_surcharge  \
# 30768          9.60           1.0        1.0                  0.00
# 30769         22.98           1.0        1.0                  2.75
# 30770         14.64           1.0        1.0                  0.00
# 30771          7.30           1.0        1.0                  0.00
# 30772          4.50           2.0        1.0                  0.00
#
#        cbd_congestion_fee  duration_min  prediction
# 30768                 0.0      4.700000    7.254809
# 30769                 0.0     13.483333   11.969174
# 30770                 0.0      9.433333   10.196504
# 30771                 0.0      4.133333    7.149974
# 30772                 0.0      0.350000    5.608404
#
# [5 rows x 22 columns]

# %%
# Define the data definitions
schema = DataDefinition(
  numerical_columns=num_features,
  categorical_columns=cat_features
)

eval_data_jan = Dataset.from_pandas(
  val_data,
  data_definition=schema
)

eval_data_feb = Dataset.from_pandas(
  feb_data,
  data_definition=schema
)

# %% [markdown]
# Data Summary Report

# %%
report = Report([
  DataSummaryPreset()
])

data_summary_eval = report.run(eval_data_jan, None)
data_summary_eval

# %%
# Can also print the JSON 
data_summary_eval.json()
# Out:
# '{"metrics": [{"id": "00404ffe284d7862baa4095093452630", "metric_name": "RowCount()", "config": {"type": "evidently:metric_v2:RowCount"}, "value": 15346.0}, {"id": "91e498263b6502661774b15eb39ea154", "metric_name": "ColumnCount()", "config": {"type": "evidently:metric_v2:ColumnCount"}, "value": 22.0}, {"id": "31b8c78bad2b7108842265cd082d5abf", "metric_name": "ColumnCount(column_type=ColumnType.Numerical)", "config": {"type": "evidently:metric_v2:ColumnCount", "tests": [], "column_type": "num"}, "value": 18.0}, {"id": "bb154bb9a843cad0d72fa3dc4983394d", "metric_name": "ColumnCount(column_type=ColumnType.Categorical)", "config": {"type": "evidently:metric_v2:ColumnCount", "tests": [], "column_type": "cat"}, "value": 1.0}, {"id": "012cbfb269361272d4773e1a68559396", "metric_name": "ColumnCount(column_type=ColumnType.Datetime)", "config": {"type": "evidently:metric_v2:ColumnCount", "tests": [], "column_type": "datetime"}, "value": 2.0}, {"id": "3f5e595e26bc8e120aadf51967bb0355", "metric_name": "ColumnCount(column_type=ColumnType.Text)", "config": {"type": "evidently:metric_v2:ColumnCount", "tests": [], "column_type": "text"}, "value": 0.0}, {"id": "ff1caea5e148b287bd5348d4bb40eccf", "metric_name": "DuplicatedRowCount()", "config": {"type": "evidently:metric_v2:DuplicatedRowCount"}, "value": 0.0}, {"id": "02fbcbd017b30a0b075d9d5a72ce2a32", "metric_name": "DuplicatedColumnsCount()", "config": {"type": "evidently:metric_v2:DuplicatedColumnsCount"}, "value": 0.0}, {"id": "4c2efb888b5c5f8afb50895b4b4abcec", "metric_name": "AlmostDuplicatedColumnsCount()", "config": {"type": "evidently:metric_v2:AlmostDuplicatedColumnsCount"}, "value": 3.0}, {"id": "9e9fa5ec57528fadbf97a35ad5b66838", "metric_name": "AlmostConstantColumnsCount()", "config": {"type": "evidently:metric_v2:AlmostConstantColumnsCount"}, "value": 5.0}, {"id": "c86e32eba7f3826051b804c0df7a97fe", "metric_name": "EmptyRowsCount()", "config": {"type": "evidently:metric_v2:EmptyRowsCount"}, "value": 0.0}, {"id": "ce527bc2e35349e7f7a2e047a57f85ca", "metric_name": "EmptyColumnsCount()", "config": {"type": "evidently:metric_v2:EmptyColumnsCount"}, "value": 0.0}, {"id": "5f958296980b95bddb41264800ab7a93", "metric_name": "ConstantColumnsCount()", "config": {"type": "evidently:metric_v2:ConstantColumnsCount"}, "value": 0.0}, {"id": "89b8d715e93a15e3acbc483410aff2f4", "metric_name": "DatasetMissingValueCount()", "config": {"type": "evidently:metric_v2:DatasetMissingValueCount"}, "value": {"count": 2.0, "share": 0.00013032712107389547}}, {"id": "4dacdcf7300140968ec1e7373bc265e9", "metric_name": "MissingValueCount(column=VendorID)", "config": {"type": "evidently:metric_v2:MissingValueCount", "column": "VendorID"}, "value": {"count": 0.0, "share": 0.0}}, {"id": "5d8c6d784594ac46e457dc775ea2bf3d", "metric_name": "UniqueValueCount(column=VendorID)", "config": {"type": "evidently:metric_v2:UniqueValueCount", "column": "VendorID"}, "value": {"counts": {"1": 1915.0, "2": 13431.0}, "shares": {"1": 0.12478821842825492, "2": 0.8752117815717451}}}, {"id": "efdf07c21bbc67148a5031f0027e8968", "metric_name": "MissingValueCount(column=RatecodeID)", "config": {"type": "evidently:metric_v2:MissingValueCount", "column": "RatecodeID"}, "value": {"count": 0.0, "share": 0.0}}, {"id": "716e9524ccbf73c9883c49c3bf8427ca", "metric_name": "MinValue(column=RatecodeID)", "config": {"type": "evidently:metric_v2:MinValue", "column": "RatecodeID"}, "value": 1.0}, {"id": "503ba8af10fc582d4999ae7035aa03fe", "metric_name": "MaxValue(column=RatecodeID)", "config": {"type": "evidently:metric_v2:MaxValue", "column": "RatecodeID"}, "value": 99.0}, {"id": "7671727ef6b67af5220c474f7b9401c7", "metric_name": "MeanValue(column=RatecodeID)", "config": {"type": "evidently:metric_v2:MeanValue", "column": "RatecodeID"}, "value": 1.1579564707415613}, {"id": "eeb63f53565fdc211580c5ddaf68273b", "metric_name": "StdValue(column=RatecodeID)", "config": {"type": "evidently:metric_v2:StdValue", "column": "RatecodeID"}, "value": 1.3402341827854 ...

# %% [markdown]
# Data Drift Report

# %%
report = Report([
  DataDriftPreset()
])

# df1: Current data to evaluate | df2: Reference dataset
drift_eval = report.run(eval_data_feb, eval_data_jan)
drift_eval

# %% [markdown]
# # Evidently Dashboard
#
# https://docs.evidentlyai.com/quickstart_ml
#
# <u>Steps</u>
#
# 1. Create a workspace
# 2. Create a project
# 3. Create a report
# 4. Save the report to the workspace
# 5. Create the dashboard

# %%
from evidently.metrics import *

from evidently.ui.workspace import Workspace
from evidently.sdk.models import PanelMetric
from evidently.sdk.panels import DashboardPanelPlot

# %%
ws = Workspace("workspace")

# %%
project = ws.create_project("NYC Taxi Data Quality Project")
project.description = "A description"
project.save()

# %%
regular_report = Report([
  DataSummaryPreset()
])

jan_summary = regular_report.run(
  reference_data=None,
  current_data=eval_data_jan,
)

# %%
report = Report([
  DataDriftPreset()
])

drift_summary = report.run(
  reference_data=eval_data_jan,
  current_data=eval_data_feb
)

# %%
# ws.add_run(project.id, jan_summary, include_data=False)
ws.add_run(project.id, drift_summary, include_data=False)
# Out:
# Report ID: 019c225a-1ce0-7744-9afe-0067d2731090
# Link: workspace\019c2255-3c38-70bd-b583-4aaab445db22\snapshots\019c225a-1ce0-7744-9afe-0067d2731090.json

# %%
# Create the dashboard
project.dashboard.add_panel(
  DashboardPanelPlot(
    title="Dataset column drift",
    subtitle="Jan and Feb drift",
    size="half",
    values=[
      PanelMetric(
        legend="Share",
        metric="DriftedColumnsCount",
        metric_labels={"value_type": "share"}
      )
    ],
    plot_params={"plot_type": "line"}
  ),
  tab="Data Drift"
)

project.dashboard.add_panel(
  DashboardPanelPlot(
    title="Predition drift",
    subtitle="""Drift in the prediction column ("class"), method: Jensen-Shannon distance""",
    size="half",
    values=[
      PanelMetric(
        legend="Drift score",
        metric="ValueDrift",
        metric_labels={"column": "trip_distance"} 
      ),
    ],
    plot_params={"plot_type": "bar"},
  ),
  tab="Data Drift",
)

# %%
project.dashboard.clear_dashboard()

# %% [markdown]
# # Testing for Grafana

# %%
ref = pd.read_parquet("../data/clean/reference.parquet")
curr = pd.read_parquet("../data/raw/green_tripdata_2025-03.parquet")

# %%
schema = DataDefinition(
  numerical_columns=num_features,
  categorical_columns=cat_features
)

df_eval = Dataset.from_pandas(
  df,
  data_definition=schema
)
df_eval
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 schema = DataDefinition(
#       2   prediction="prediction",
#       3   numerical_columns=num_features,
#       4   categorical_columns=cat_features
#       5 )
#       7 df_eval = Dataset.from_pandas(
#       8   df,
#       9   data_definition=schema
#      10 )
#      11 df_eval
#
# TypeError: DataDefinition.__init__() got an unexpected keyword argument 'prediction'

# %%
report = Report([
  DataDriftPreset(),
  DatasetMissingValueCount()
])

report.run(
  reference
)

# %%
# %load_ext watermark
# %watermark
