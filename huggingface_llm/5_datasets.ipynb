# %% [markdown]
# # Datasets
#
# `Datasets` is HF internal data loading and processing library

# %% [markdown]
# | Date | User | Change Type | Remarks |
# | ---- | ---- | ----------- | ------- |
# | 09/12/2025   | Martin | Created   | Notebook for Ch5 for HF LLM tutorial |

# %% [markdown]
# # Content
#
# * [Introduction](#introduction)

# %%
# %load_ext watermark

# %% [markdown]
# # Introduction
#
# ❓Questions to Answer:
#
# - What do you do when your dataset is not on the Hub?
# - How can you slice and dice a dataset? (And what if you really need to use Pandas?)
# - What do you do when your dataset is huge and will melt your laptop’s RAM?
# - What the heck are “memory mapping” and Apache Arrow?
# - How can you create your own dataset and push it to the Hub?

# %% [markdown]
# # Local and Remote Datasets
#
# For datasets that are not on the HF Hub
#
# ![datasets](./assets/datasets.png)
#
# - Specify the type of loading script in the `load_dataset()` function and corresponding `data_files` argument

# %%
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %watermark
